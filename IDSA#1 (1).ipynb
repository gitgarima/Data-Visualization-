# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import gridspec
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

# %%
dataset = pd.read_csv(r'C:\Users\HP\OneDrive\Desktop\Introduction to Data Science\dsassign#1.csv')
dataset
# Out:
#      AGE  SEX   BMI      BP   S1     S2    S3    S4      S5   S6    Y
# 0     59    2  32.1  101.00  157   93.2  38.0  4.00  4.8598   87  151
# 1     48    1  21.6   87.00  183  103.2  70.0  3.00  3.8918   69   75
# 2     72    2  30.5   93.00  156   93.6  41.0  4.00  4.6728   85  141
# 3     24    1  25.3   84.00  198  131.4  40.0  5.00  4.8903   89  206
# 4     50    1  23.0  101.00  192  125.4  52.0  4.00  4.2905   80  135
# ..   ...  ...   ...     ...  ...    ...   ...   ...     ...  ...  ...
# 437   60    2  28.2  112.00  185  113.8  42.0  4.00  4.9836   93  178
# 438   47    2  24.9   75.00  225  166.0  42.0  5.00  4.4427  102  104
# 439   60    2  24.9   99.67  162  106.6  43.0  3.77  4.1271   95  132
# 440   36    1  30.0   95.00  201  125.2  42.0  4.79  5.1299   85  220
# 441   36    1  19.6   71.00  250  133.2  97.0  3.00  4.5951   92   57
#
# [442 rows x 11 columns]

# %%
dataset.head()
# Out:
#    AGE  SEX   BMI     BP   S1     S2    S3   S4      S5  S6    Y
# 0   59    2  32.1  101.0  157   93.2  38.0  4.0  4.8598  87  151
# 1   48    1  21.6   87.0  183  103.2  70.0  3.0  3.8918  69   75
# 2   72    2  30.5   93.0  156   93.6  41.0  4.0  4.6728  85  141
# 3   24    1  25.3   84.0  198  131.4  40.0  5.0  4.8903  89  206
# 4   50    1  23.0  101.0  192  125.4  52.0  4.0  4.2905  80  135

# %%
dataset.tail()
# Out:
#      AGE  SEX   BMI      BP   S1     S2    S3    S4      S5   S6    Y
# 437   60    2  28.2  112.00  185  113.8  42.0  4.00  4.9836   93  178
# 438   47    2  24.9   75.00  225  166.0  42.0  5.00  4.4427  102  104
# 439   60    2  24.9   99.67  162  106.6  43.0  3.77  4.1271   95  132
# 440   36    1  30.0   95.00  201  125.2  42.0  4.79  5.1299   85  220
# 441   36    1  19.6   71.00  250  133.2  97.0  3.00  4.5951   92   57

# %%
dataset.dtypes
# Out:
# AGE      int64
# SEX      int64
# BMI    float64
# BP     float64
# S1       int64
# S2     float64
# S3     float64
# S4     float64
# S5     float64
# S6       int64
# Y        int64
# dtype: object

# %%
dataset.isnull().sum()
# Out:
# AGE    0
# SEX    0
# BMI    0
# BP     0
# S1     0
# S2     0
# S3     0
# S4     0
# S5     0
# S6     0
# Y      0
# dtype: int64

# %%
dataset.fillna(25)
# Out:
#      AGE  SEX   BMI      BP   S1     S2    S3    S4      S5   S6    Y
# 0     59    2  32.1  101.00  157   93.2  38.0  4.00  4.8598   87  151
# 1     48    1  21.6   87.00  183  103.2  70.0  3.00  3.8918   69   75
# 2     72    2  30.5   93.00  156   93.6  41.0  4.00  4.6728   85  141
# 3     24    1  25.3   84.00  198  131.4  40.0  5.00  4.8903   89  206
# 4     50    1  23.0  101.00  192  125.4  52.0  4.00  4.2905   80  135
# ..   ...  ...   ...     ...  ...    ...   ...   ...     ...  ...  ...
# 437   60    2  28.2  112.00  185  113.8  42.0  4.00  4.9836   93  178
# 438   47    2  24.9   75.00  225  166.0  42.0  5.00  4.4427  102  104
# 439   60    2  24.9   99.67  162  106.6  43.0  3.77  4.1271   95  132
# 440   36    1  30.0   95.00  201  125.2  42.0  4.79  5.1299   85  220
# 441   36    1  19.6   71.00  250  133.2  97.0  3.00  4.5951   92   57
#
# [442 rows x 11 columns]

# %%
dataset.boxplot()
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=dataset['BMI'])
# Out:
# <AxesSubplot:xlabel='BMI'>

# %%
fig, ax = plt.subplots(figsize=(16,8))
ax.scatter(dataset['S3'], dataset['BMI'])
ax.set_xlabel('S3 of the people in dataset')
ax.set_ylabel('BMI of the people in dataset')
plt.show()

# %%
dataset.dtypes
# Out:
# AGE      int64
# SEX      int64
# BMI    float64
# BP     float64
# S1       int64
# S2     float64
# S3     float64
# S4     float64
# S5     float64
# S6       int64
# Y        int64
# dtype: object

# %%
c = pd.Categorical(['S1', 'S2', 'S3', 'S4',
                     'S5', 'S6' ], ordered = True)
print (c)
# Out:
# ['S1', 'S2', 'S3', 'S4', 'S5', 'S6']
# Categories (6, object): ['S1' < 'S2' < 'S3' < 'S4' < 'S5' < 'S6']

# %%
c1 = pd.Categorical(['AGE', 'SEX', 'BMI', 'BP',
                     'Y'])
print (c1)
# Out:
# ['AGE', 'SEX', 'BMI', 'BP', 'Y']
# Categories (5, object): ['AGE', 'BMI', 'BP', 'SEX', 'Y']

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AGE     442 non-null    int64
#  1   SEX     442 non-null    int64
#  2   BMI     442 non-null    float64
#  3   BP      442 non-null    float64
#  4   S1      442 non-null    int64
#  5   S2      442 non-null    float64
#  6   S3      442 non-null    float64
#  7   S4      442 non-null    float64
#  8   S5      442 non-null    float64
#  9   S6      442 non-null    int64
#  10  Y       442 non-null    int64
# dtypes: float64(6), int64(5)
# memory usage: 38.1 KB

# %%
dataset.describe()
# Out:
#               AGE         SEX         BMI          BP          S1          S2  \
# count  442.000000  442.000000  442.000000  442.000000  442.000000  442.000000
# mean    48.518100    1.468326   26.375792   94.647014  189.140271  115.439140
# std     13.109028    0.499561    4.418122   13.831283   34.608052   30.413081
# min     19.000000    1.000000   18.000000   62.000000   97.000000   41.600000
# 25%     38.250000    1.000000   23.200000   84.000000  164.250000   96.050000
# 50%     50.000000    1.000000   25.700000   93.000000  186.000000  113.000000
# 75%     59.000000    2.000000   29.275000  105.000000  209.750000  134.500000
# max     79.000000    2.000000   42.200000  133.000000  301.000000  242.400000
#
#                S3          S4          S5          S6           Y
# count  442.000000  442.000000  442.000000  442.000000  442.000000
# mean    49.788462    4.070249    4.641411   91.260181  152.133484
# std     12.934202    1.290450    0.522391   11.496335   77.093005
# ...

# %%
g = sns.pairplot(data=dataset[['AGE' ,'SEX','BMI', 'BP']], hue='BP', dropna=True, height=3, aspect=2, palette=('cubehelix'), markers='o')
g.axes[2,1].set_xlim((0,140))
g.axes[1,2].set_xlim((0,60))
# Out:
# (0.0, 60.0)

# %%
g = sns.PairGrid(data=dataset[['AGE' ,'BMI','BP', 'Y']], hue='Y', dropna=True, height=3)
g = g.map_upper(plt.scatter)

# %%
dataset = pd.DataFrame(dataset,columns=['AGE','SEX','BMI','BP','S1','S2','S3','S4','S5','S6','Y'])
corrMatrix = dataset.corr()
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %%
limitation: dataset is small and does not contain descriptive data.
